# %% [markdown]
# # PSF Photometry using effective PSF models (in python!)

# %% [markdown]
# We present a software stack for fitting the PSF models developed by J Anderson for HST/WFC3 to perform high precision PSF photometry.  In general, the process is as follows:
# 1. Find and fit stars in each image using the PSF model
# 2. Align the images using the PSF fitted catalogs
# 3. Match the stars and collate/average the measurements into one final catalog.
# In this notebook, we show a simple workflow for performing these tasks using the psf_tools package.

# %% [markdown]
# ### Versions!

# %% [markdown]
# NOTE: These tools require an installation of astroconda, using python 3.6, and photutils >= 0.7.1.  It also requires astroquery and skimage >=0.15.0

# %% [markdown]
# # Table of Contents
# 0. [Data Download](#dl)
#
# 1a. [Fortran Interface](#fortran)
#
# 1b. [Python Interface](#python)
#
#
# 2. [Align Images](#align)
#
#
# 3. [Collate/Average Measurements](#average)
#
#
# 4. [Results](#results)

# %%
# some parameters we will use consistently
hmin = 5
fmin = 1000.
pmax= 66000.

# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import os

from astropy.io import fits
from astropy.table import Table
from astroquery.mast import Observations

from psf_tools import run_hst1pass, run_python_psf_fitting, align_images, make_final_table, \
                    match_final_catalogs, match_to_master_catalog
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol

# %%
import matplotlib as mpl
mpl.rcParams['xtick.labelsize'] = 10
plt.rcParams.update({'axes.titlesize' : '18',
                     'axes.labelsize' : '14',
                     'xtick.labelsize' : '14',
                     'ytick.labelsize' : '14'})
COLOR = 'black'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR
# %matplotlib inline

# %% [markdown]
# # 0. First, download some data
# <a id="dl">

# %% [markdown]
# Let's download some data from the outer regions of Omega Cen to start.  We will use images in 2 filters, 2 epochs each.

# %%
cd oc/
# Out:
# /grp/hst/wfc3i/irivera/repos/wfc3_photometry/oc

# %%
obsTable = Observations.query_criteria(project='HST',proposal_id='14118', obs_id='ICTJ4[5678]*', obstype='all')
products = Observations.get_product_list(obsTable)
filtered_products = Observations.filter_products(products,mrp_only=False, productSubGroupDescription='FLC')
dl_tbl = Observations.download_products(filtered_products,mrp_only=False)
files = []
for f in dl_tbl['Local Path']:
    filename = os.path.split(f)[-1]
    files.append(filename)
    if not os.path.exists(filename):
        shutil.move(f, '.')
# Out:
# INFO: Found cached file ./mastDownload/HST/hst_14118_45_wfc3_uvis_f814w_ictj45ah/hst_14118_45_wfc3_uvis_f814w_ictj45ah_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_45_wfc3_uvis_f814w_ictj45aj/hst_14118_45_wfc3_uvis_f814w_ictj45aj_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_45_wfc3_uvis_f814w_ictj45b9/hst_14118_45_wfc3_uvis_f814w_ictj45b9_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_46_wfc3_uvis_f814w_ictj46cs/hst_14118_46_wfc3_uvis_f814w_ictj46cs_flc.fits with expected size 169044480. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_46_wfc3_uvis_f814w_ictj46cu/hst_14118_46_wfc3_uvis_f814w_ictj46cu_flc.fits with expected size 169044480. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_46_wfc3_uvis_f814w_ictj46cz/hst_14118_46_wfc3_uvis_f814w_ictj46cz_flc.fits with expected size 169044480. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_47_wfc3_uvis_f606w_ictj47uz/hst_14118_47_wfc3_uvis_f606w_ictj47uz_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_47_wfc3_uvis_f606w_ictj47v1/hst_14118_47_wfc3_uvis_f606w_ictj47v1_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_47_wfc3_uvis_f606w_ictj47v4/hst_14118_47_wfc3_uvis_f606w_ictj47v4_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_48_wfc3_uvis_f606w_ictj48d7/hst_14118_48_wfc3_uvis_f606w_ictj48d7_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_48_wfc3_uvis_f606w_ictj48d9/hst_14118_48_wfc3_uvis_f606w_ictj48d9_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/hst_14118_48_wfc3_uvis_f606w_ictj48dg/hst_14118_48_wfc3_uvis_f606w_ictj48dg_flc.fits with expected size 169263360. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj45ahq/ictj45ahq_flc.fits with expected size 169032960. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj45ajq/ictj45ajq_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj45b9q/ictj45b9q_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj46csq/ictj46csq_flc.fits with expected size 168929280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj46cuq/ictj46cuq_flc.fits with expected size 168929280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj46czq/ictj46czq_flc.fits with expected size 168929280. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj47uzq/ictj47uzq_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj47v1q/ictj47v1q_flc.fits with expected size 169032960. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj47v4q/ictj47v4q_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj48d7q/ictj48d7q_flc.fits with expected size 169032960. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj48d9q/ictj48d9q_flc.fits with expected size 169148160. [astroquery.query]
# INFO: Found cached file ./mastDownload/HST/ictj48dgq/ictj48dgq_flc.fits with expected size 169148160. [astroquery.query]

# %% [markdown]
# ### Multiple filters in downloaded data, only look at/fit one band at a time

# %%
files = glob.glob('ictj*flc.fits')

# %%
files
# Out:
# ['ictj47v1q_flc.fits',
#  'ictj48dgq_flc.fits',
#  'ictj45ahq_flc.fits',
#  'ictj46cuq_flc.fits',
#  'ictj45ajq_flc.fits',
#  'ictj48d7q_flc.fits',
#  'ictj45b9q_flc.fits',
#  'ictj46czq_flc.fits',
#  'ictj47v4q_flc.fits',
#  'ictj48d9q_flc.fits',
#  'ictj46csq_flc.fits',
#  'ictj47uzq_flc.fits']

# %%
input_images =[im for im in  sorted(files) if fits.getval(im, 'FILTER')== 'F814W']

# %%
input_images
# Out:
# ['ictj45ahq_flc.fits',
#  'ictj45ajq_flc.fits',
#  'ictj45b9q_flc.fits',
#  'ictj46csq_flc.fits',
#  'ictj46cuq_flc.fits',
#  'ictj46czq_flc.fits']

# %% [markdown]
# ### Lets fit just the longer exposures in this example

# %%
input_images = [im for im in input_images if fits.getval(im, 'EXPTIME') > 200.]

# %%
for im in input_images:
    print(im, fits.getval(im, 'exptime'), fits.getval(im, 'date-obs'), fits.getval(im, 'filter'))
# Out:
# ictj45ajq_flc.fits 1253.0 2016-06-27 F814W
# ictj45b9q_flc.fits 1345.0 2016-06-27 F814W
# ictj46cuq_flc.fits 1253.0 2016-07-04 F814W
# ictj46czq_flc.fits 1345.0 2016-07-04 F814W

# %% [markdown]
# # 1a. Fortran Interface<a id="fortran"></a>

# %% [markdown]
# ### See input options:

# %%
run_hst1pass?
# Out:
# Signature:
# run_hst1pass(
#     input_images,
#     hmin=5,
#     fmin=1000,
#     pmax=99999,
#     out='xympqks',
#     executable_path=None,
#     **kwargs,
# )
# Docstring:
# Run hst1pass.e Fortran code on images to produce initial catalogs.
#
# This function runs the Fortran routine hst1pass.e, on a set of
# input images.  This is Jay Anderson's PSF fitting single pass
# photometry code.  The fortran code must first be compiled for
# this code to run.  Running this code outputs one catalog for
# each input image, and saves those files to disk.  More parameters
# from the hst1pass.e code may be added to this interface in the
# future.  The original Fortran executable can also be called from
# the command line if desired.
#
# Parameters
# ----------
# input_images : list
#     List of image filenames (strings).  Must be fits files.
# hmin : int
#     Minimum separation between stars. Default 5
# fmin : int, optional
#     The minimum flux (in image units) a source must have to be
#     included in the output catalogs. Default 1000.
# pmax : int, optional
#     The maximum flux (in image units) a source can have in the
#     peak pixel to be included in the output catalogs.  Used to
#     filter out saturated sources.  Default 99999.
# out : str, optional
#     The measurments to be recorded in the output catalogs.  Each
#     character corresponds to one output column.  The default is
#     'xympqks' which gives: x coordinate, y coordinate, instrumental
#     magnitude, peak pixel value, quality of fit (0 is perfect
#     fit), the chip the star was detected on (chip 1 or chip 2
#     for UVIS), and the sky value.  If being used with other functions
#     in this package x, y, m, q, k, and s must be included in the
#     outputs.  More measurements will be supported at a later date.
# executable_path : str, optional
#     The path to the hst1pass.e compiled executable.  If None (default),
#     the code is assumed to be in the psf_tools directory.
#
# Returns
# -------
# expected_output_list : list
#     List of the output catalogs from running hst1pass
# File:      /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/PSFPhot.py
# Type:      function

# %% [markdown]
# In general, the default parameters passed are suitable for most use cases.  The only parameters that would be recommeneded to edit would be `fmin`, `pmax`, and `hmin`.  There are also extra keyword arguments that can be passed to the call, but support for those parameters is not guaranteed.

# %% [markdown]
# To see other keyword arguments, run the fortran executable with no arguments

# %%
import psf_tools
print(psf_tools.PSFPhot._get_exec_path())
# Out:
# /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_linux.e

# %% [markdown]
# Replace the path below with whatever was output above

# %%
! /Users/vbajaj/Documents/wfc3_photometry/wfc3_photometry/psf_tools/hst1pass_darwin.e
# Out:
# /bin/bash: /Users/vbajaj/Documents/wfc3_photometry/wfc3_photometry/psf_tools/hst1pass_darwin.e: No such file or directory

# %% [markdown]
# ### Run the PSF photometry

# %% [markdown]
# The executable is ran in the following cell using the Fortran engine.  Supplying `focus=-1` parameter tells the software to determine and use the focus dependent PSF library.  If not supplied then the standard (spatially dependent, but non focus dependent PSFs are used.

# %%
catalogs = run_hst1pass(input_images=input_images, hmin=hmin, fmin=fmin, pmax=pmax)
# Out:
# Using PSF file STDPSF_WFC3UV_F814W.fits
# /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_linux.e HMIN=5 FMIN=1000.0 PMAX=66000.0 OUT=xympqks GDC=NONE PSF=STDPSF_WFC3UV_F814W.fits ictj45ajq_flc.fits ictj45b9q_flc.fits ictj46cuq_flc.fits ictj46czq_flc.fits
# b''
# b''
# b'ARG0000  /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_linux.e'
# b'ARG0001  HMIN=5'
# b'ARG0002  FMIN=1000.0'
# b'ARG0003  PMAX=66000.0'
# b'ARG0004  OUT=xympqks'
# b'--->    NLISTs =            1'
# b'--->    NITEMs =            7'
# b'--->   OUTLIST = xympqks'
# b'ARG0005  GDC=NONE'
# b'ARG0006  PSF=STDPSF_WFC3UV_F814W.fits'
# b'ARG0007  ictj45ajq_flc.fits'
# b'---> NIM0001 ictj45ajq_flc.fits'
# b'ARG0008  ictj45b9q_flc.fits'
# b'---> NIM0002 ictj45b9q_flc.fits'
# b'ARG0009  ictj46cuq_flc.fits'
# b'---> NIM0003 ictj46cuq_flc.fits'
# b'ARG0010  ictj46czq_flc.fits'
# b'---> NIM0004 ictj46czq_flc.fits'
# b''
# b''
# b''
# b''
# b'OUTPUT FROM PROGRAM hst2xym'
# b''
# b'/grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_linux.e'
# b''
# b'HMIN:   5'
# b'FMIN:              1000.0'
# b'PMAX:             66000.0'
# b'PSFFILE0: STDPSF_WFC3UV_F814W.fits'
# b'GDCFILE0: NONE'
# b'PSFFILEI: STDPSF_WFC3UV_F814W.fits'
# b'GDCFILEI: AUTO'
# b'DOAPPHOT: F'
# b''
# b'DOSATD: T'
# b'GDC_INP: AUTO'
# b'GDC_LIB: NONE'
# b'GDC_USE: NONE'
# b'PSF_INP: STDPSF_WFC3UV_F814W.fits'
# b'PSF_LIB: NONE'
# b'PERT_INP: NONE'
# b'NPERTs: 0'
# b'WCSMODE: FIND'
# b'KSEL:  0'
# b'QMAX:  9.990'
# b'CMIN: -1.000'
# b'CMAX:  0.100'
# b'QCAND: F'
# b''
# b'NIMs:     4'
# b'NIM:            1 ictj45ajq_flc.fits'
# b'NIM:            2 ictj45b9q_flc.fits'
# b'NIM:            3 ictj46cuq_flc.fits'
# b'NIM:            4 ictj46czq_flc.fits'
# b''
# b'enter subroutine sub_hst2xym: FILENAME = ictj45ajq_flc.fits'
# b''
# b'ENTER sub_hst2xym -- ictj45ajq_flc.fits'
# b'ENTER sub_hst2xym -- As:      0'
# b'ENTER sub_hst2xym --  V:      2'
# b''
# b'DOAPPHOT:  F'
# b'HHo:           11'
# b'0001 #'
# b'0002 #--------------------------------------------'
# b'0003 # ARGUMENTS'
# b'0004 #--------------------------------------------'
# b'0005 #   ARG0000: /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_lin'
# b'0006 #   ARG0001: HMIN=5'
# b'0007 #   ARG0002: FMIN=1000.0'
# b'0008 #   ARG0003: PMAX=66000.0'
# b'0009 #   ARG0004: OUT=xympqks'
# b'0010 #   ARG0005: GDC=NONE'
# b'0011 #   ARG0006: PSF=STDPSF_WFC3UV_F814W.fits'
# b'HMIN:            5'
# b'FMIN:    1000.00000'
# b'PMAX:    66000.0000'
# b'PSFFILE_INP: STDPSF_WFC3UV_F814W.fits'
# b'GDCFILE_INP: NONE'
# b'HIFLAG:        70000'
# b'WCSMODE: FIND'
# b'DOSATD:  T'
# b'SHOW_ALL: NO'
# b'SHOW_USE: NO'
# b'SHOW_FND: NO'
# b'SHOW_REF: NO'
# b'SHOW_SUB: NO'
# b'SHOW_MSK: X'
# b'NPERTs:            0'
# b'FOCUS_LEVi:    0.00000000'
# b'KSEL:            0'
# b'QMAX:    9.98999977'
# b'CMIN:   -1.00000000      0.100000001'
# b'QCAND:  F'
# b'IMIN:         -999        9999'
# b'JMIN:         -999        9999'
# b'DOHSORT:  F'
# b'DOMSORT:  F'
# b'CATMAT: NONE'
# b'CATREG: NONE'
# b'FILENAME: ictj45ajq_flc.fits'
# b'NIMu:            1'
# b'NIMs:            4'
# b''
# b'---> HHo:           11'
# b'---> dirstrip filename...'
# b'---> dirstrip filename...'
# b'---> query...'
# b'---> find_rdate...'
# b'---> rDATuu...   2016.4878425598145'
# b'---> FILTNAME...'
# b'---> _NPRTMX_:            5'
# b'---> query_hdre: INSTRUM...'
# b''
# b'QUERY HEADER:'
# b"INSTRUME: 'WFC3  '"
# b"DETECTOR: 'UVIS'"
# b''
# b'READ IN WFC3/UVIS IMAGE...ictj45ajq_flc.fits'
# b'WFC3UV CRPIX1_INST: 2048.0000000'
# b'WFC3UV CRPIX2_INST: 1026.0000000'
# b''
# b'ENTER PEAK_SAT...   65000.0000'
# b'i:         1000'
# b'i:         2000'
# b'i:         3000'
# b'i:         4000'
# b''
# b'FIND MAX_CONTIG...'
# b'NIT:      2    21033'
# b'NIT:      3        3'
# b'NIT:      4        0'
# b''
# b'Do sat_phot apphot...'
# b'0017 2324   -14.9020    44.38       913677.2        3       40 00001   0.904662       930451.9     930451.9'
# b'0019 0415   -14.0455    47.45       415162.4        0       25 00002   0.802953       383515.4     383515.4'
# b'0021 0193   -14.6263    55.92       708803.1        2       30 00003   0.836958       706903.6     706903.6'
# b'0027 2940   -15.1661    51.18      1165338.9        6       46 00004   0.919764      1176730.5    1176730.5'
# b'0028 2131   -15.3495    65.44      1379809.9        9       53 00005   0.926299      1304099.5    1304099.5'
# b'0032 0173   -15.1138    67.86      1110528.0        7       56 00006   0.966890      1171190.5    1171190.5'
# b'0033 4033   -14.5506    45.99       661067.9        2       30 00007   0.826695       625079.8     625079.8'
# b'0052 2560   -12.5683    48.19       106496.9        0       25 00008   0.800915       100760.6     100760.6'
# b'0058 1521   -14.6247    43.08       707769.7        1       35 00009   0.874089       701736.1     701736.1'
# b'---->     rDE0:   -47.476943969726562'
# b'WCSMODE: FIND          NGC5139 OMC      201.69124 -47.47694           0.00      0.00'
# b'CALL FILL_WCS_INFO OBJ_NAME: NGC5139 OMC'
# b'CALL FILL_WCS_INFO   CRPIX1:    0.0000000000000000        0.0000000000000000'
# b'CALL FILL_WCS_INFO   CRVAL1:    201.69123840332031       -47.476943969726562'
# b'FIND_HISTMODE...'
# b'#  HISTMODE...  pixc (W/ SKYSUB):    35.72'
# b'DOAPPHOT:  F'
# b'--->  FOCUS_LEVi:    0.00000000'
# b'--->  FOCUS_LEVu:    0.00000000'
# b'---> PSFFILE_LIB: STDPSF_WFC3UV_F814W.fits'
# b'---> PSFFILE_USE: STDPSF_WFC3UV_F814W.fits'
# b'---> PSFFILE_PFF: STDPSF_WFC3UV_F814W.fits'
# b''
# b'HERE IS THE INFO ON THE PSF TO BE USED...'
# b''
# b'PSFFILE_LIB: STDPSF_WFC3UV_F814W.fits'
# b''
# b''
# b'*************************************'
# b'*************************************'
# b'**'
# b'**  GO THRU IMAGE AND FIND PEAKS...'
# b'**'
# b'**     HMIN:            5'
# b'**     FMIN:    1000.00000'
# b'**     PMAX:    66000.0000'
# b'**     NIMu:            1'
# b'**     NIMs:            4'
# b'**'
# b'** LOFLAG_I:          -50'
# b'** HIFLAG_I:        65000'
# b'** HIFLAG  :        70000'
# b'**'
# b'**   NAXIS1:         4096'
# b'**   NAXIS2:         4096'
# b'**'
# b'*************************************'
# b'*************************************'
# b''
# b''
# b'------- -------- -------- ------- ------|- - -|-------| ----- ----- ----- -----| ----- ----- ----- -----| ------- ------- -------'
# b'N    XCEN     YCEN     MAG     SKY |MiSoS|   PCEN|   P02   P03   P04   P05|   P06   P07   P08   P09|    mSKY    F2x2 F2x2-SK'
# b'------- -------- -------- ------- ------|- - -|-------| ----- ----- ----- -----| ----- ----- ----- -----| ------- ------- -------'
# b'SHOW_ALL: NO'
# b'SHOW_USE: NO'
# b'SHOW_FND: NO'
# b'SHOW_SUB: NO'
# b''
# b'ENTER iit,jjt...'
# b'NAXIS1:         4096'
# b'NAXIS2:         4096'
# b'DOAPPHOT:  F'
# b''
# b'1 3161.462    5.393  -8.226   32.9|5 5 8|    465|   269    45   172    54|   402    53    41    38|      32    1309    1177'
# b'2 3456.623    5.509 -12.244   61.4|5 6 9|  10127|  2650  7789  9999  2266|  2368  8510   982  1644|      61   36426   36094'
# b'3 4090.566    4.816 -12.902   45.9|51215|  20545|  4004 18468  6400 12443|  1723  6969  4768 10242|      45   61699   61260'
# b'4  126.940    6.090 -13.212   66.3|51215|  31042| 13607 16289 17604 13391|  7065  9603  6561  6559|      66   74540   74046'
# b'5 1698.599    6.204  -9.605   38.8|5 6 9|   1404|    53   434   342  1211|    47   586    51    94|      38    3144    2982'
# b'6 1709.451    5.816  -9.506   40.3|5 5 8|   1256|   560   318   212   205|   101   806   532    69|      40    2594    2418'
# b'7 1840.799    5.890 -12.006   46.7|51114|  10456|  3330  6534  3890  5739|  1393  2645  2095  3241|      46   25972   25732'
# b'CRVAL2:   -47.630745553094997      -47:37:50.68'
# b''
# b'OUTPUT LISTS...'
# b'NLISTs:            1'
# b'SETUPa---           26'
# b'SETUPb ---        14604'
# b''
# b'--------------'
# b'FIND SPACING:'
# b'--------------'
# b'F01 (05:14)     u -- u ref-frame'
# b'F02 (04:14)     v -- v ref-frame'
# b'F03 (02:08)     M -- instl mag (1000s)'
# b'F04 (01:08)     x -- raw detector x pos'
# b'F05 (01:08)     y -- raw detector y pos'
# b'F06 (02:08)     m -- instl mag'
# b'F07 (02:02)     k -- detector chip no'
# b'F08 (01:08)     X -- dist-cor x posn'
# b'F09 (01:08)     Y -- dist-cor y posn'
# b'F10 (02:02)     h -- local isolation'
# b'F11 (04:08)     H -- list-based isolatn'
# b'F12 (05:15)     r -- RA (deg)'
# b'F13 (05:15)     d -- Dec (deg)'
# b'F14 (01:11)     R -- RA (sexig)'
# b'F15 (01:12)     D -- Dec (sexig)'
# b'F16 (03:06)     i -- peak pixel column'
# b'F17 (03:06)     j -- peak pixel row'
# b'F18 (05:12)     p -- peak pixel value'
# b'F19 (08:12)     q -- quality of fit'
# b'F20 (07:12)     c -- chisq of fit'
# b'F21 (05:14)     U -- u ref-frame (corr)'
# b'F22 (04:14)     V -- v ref-frame (corr)'
# b'F23 (01:01)     k -- chip number'
# b'F24 (01:02)     K -- chip number (w/K)'
# b'F25 (04:10)     s -- sky value'
# b'F26 (01:06)     n -- star number'
# b''
# b'*********************'
# b'***'
# b'*** NLISTs:            1'
# b'***'
# b'*********************'
# b''
# b'enter subroutine sub_hst2xym: FILENAME = ictj45b9q_flc.fits'
# b''
# b'ENTER sub_hst2xym -- ictj45b9q_flc.fits'
# b'ENTER sub_hst2xym -- As:      0'
# b'ENTER sub_hst2xym --  V:      2'
# b''
# b'DOAPPHOT:  F'
# b'HHo:           11'
# b'0001 #'
# b'0002 #--------------------------------------------'
# b'0003 # ARGUMENTS'
# b'0004 #--------------------------------------------'
# b'0005 #   ARG0000: /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/hst1pass_lin'
# b'0006 #   ARG0001: HMIN=5'
# b'0007 #   ARG0002: FMIN=1000.0'
# b'0008 #   ARG0003: PMAX=66000.0'
# b'0009 #   ARG0004: OUT=xympqks'
# b'0010 #   ARG0005: GDC=NONE'
# b'0011 #   ARG0006: PSF=STDPSF_WFC3UV_F814W.fits'
# b'HMIN:            5'
# b'FMIN:    1000.00000'
# b'PMAX:    66000.0000'
# b'PSFFILE_INP: STDPSF_WFC3UV_F814W.fits'
# b'GDCFILE_INP: NONE'
# b'HIFLAG:        70000'
# b'WCSMODE: FIND'
# b'DOSATD:  T'
# b'SHOW_ALL: NO'
# b'SHOW_USE: NO'
# b'SHOW_FND: NO'
# b'SHOW_REF: NO'
# b'SHOW_SUB: NO'
# b'SHOW_MSK: X'
# b'NPERTs:            0'
# b'FOCUS_LEVi:    0.00000000'
# b'KSEL:            0'
# b'QMAX:    9.98999977'
# b'CMIN:   -1.00000000      0.100000001'
# b'QCAND:  F'
# b'IMIN:         -999        9999'
# b'JMIN:         -999        9999'
# b'DOHSORT:  F'
# b'DOMSORT:  F'
# b'CATMAT: NONE'
# b'CATREG: NONE'
# b'FILENAME: ictj45b9q_flc.fits'
# b'NIMu:            2'
# b'NIMs:            4'
# b''
# b'---> HHo:           11'
# b'---> dirstrip filename...'
# b'---> dirstrip filename...'
# b'---> query...'
# b'---> find_rdate...'
# b'---> rDATuu...   2016.4878864288330'
# b'---> FILTNAME...'
# b'---> _NPRTMX_:            5'
# b'---> query_hdre: INSTRUM...'
# b''
# b'QUERY HEADER:'
# b"INSTRUME: 'WFC3  '"
# b"DETECTOR: 'UVIS'"
# b''
# b'READ IN WFC3/UVIS IMAGE...ictj45b9q_flc.fits'
# b'WFC3UV CRPIX1_INST: 2048.0000000'
# b'WFC3UV CRPIX2_INST: 1026.0000000'
# b''
# b'ENTER PEAK_SAT...   65000.0000'
# b'i:         1000'
# b'i:         2000'
# b'i:         3000'
# b'i:         4000'
# b''
# b'FIND MAX_CONTIG...'
# b'NIT:      2    26378'
# b'NIT:      3        6'
# b'NIT:      4        0'
# b''
# b'Do sat_phot apphot...'
# b'0012 3793   -16.1781    61.25      2959634.2       25      107 00001   0.994366      2343750.0    2343750.0'
# b'0023 1541   -14.7104    37.62       765867.6        0       36 00002   0.867603       720999.5     720999.5'
# b'0026 2622   -14.5172    57.31       641035.9        1       30 00003   0.834627       617764.8     617764.8'
# b'0031 3071   -14.4458    48.50       600239.2        1       30 00004   0.836894       537689.9     537689.9'
# b'0047 0472   -14.7137    45.83       768231.0        4       40 00005   0.911140       765001.4     765001.4'
# b'0052 3294   -12.4651    33.67        96833.3        0       25 00006   0.800803        84531.3      84531.3'
# b'0057 1308   -15.0001    39.83      1000135.1        4       47 00007   0.916652       979217.4     979217.4'
# b'0074 2129   -16.5137    71.17      4031519.8       38      137 00008   1.004942      3428954.0    3428954.0'
# b'0075 0066   -14.4835    68.17       621417.4        1       30 00009   0.836288       620284.8     620284.8'
# b'0075 2534   -14.2217    51.20       488283.1        0       25 00010   0.801006       441531.5     441531.5'
# b'0078 0190   -18.0173   141.45     16102925.0      187      510 00011   1.040093     11985510.0   11985510.0'
# b'0281 2484   -19.8070   671.99     83712704.0     1174     2744 00051   1.051378     39087480.0   39087480.0'
# b'0662 3598   -17.7748   133.27     12880442.0      159      445 00100   1.037874      8435590.0    8435590.0'
# b'1370 0458   -20.4384   909.58    149745472.0     1780     4121 00189   1.053614     66159384.0   66159384.0'
# b'1481 0179   -14.6592    47.83       730593.7        2       30 00200   0.834215       731122.6     731122.6'
# b'2321 2584   -15.1261    45.33      1123162.2        0       45 00300   0.914375      1127213.8    1127213.8'
# b'3068 1017   -14.6585    43.92       730108.9        3       36 00400   0.876054       689324.5     689324.5'
# b'3955 0560   -20.4502   833.67    151381808.0     1818     4145 00477   1.056235     67083676.0   67083676.0'
# b''
# b"INSTRUMENT: 'WFC3  '"
# b"DETECTOR: 'UVIS'"
# b''
# b'pixc(500,500):    44.6031265'
# b'CRPIX1_INST: 2048.00000001026.0000000'
# b'CRPIX1_xgc0: 2048.00000001026.0000000'
# b'CRVAL1_INST:  201.5364878 -47.6364104'
# b'CD1_1_INST:   -0.0000063  -0.0000091'
# b'CD2_1_INST:   -0.0000091   0.0000063'
# b'LOFLAG_INST:      -50'
# b'HIFLAG_INST:    65000'
# b'BDRY_XR(1,1):    1.0000000   1.0000000'
# b'BDRY_XR(2,1): 4095.0000000   1.0000000'
# b'BDRY_XR(3,1): 4095.00000002047.0000000'
# b'BDRY_XR(4,1):    1.00000002047.0000000'
# b'FILT_INST: F814W'
# b'EXPT_INST:   1345.00'
# b'RDAT_INST:   2016.49'
# b'PROP_INST: 14118'
# b'RA2SEXIG:  201.536487813:26:08.7'
# b'DE2SEXIG:  -47.6364104-47:38:11.'
# b''
# b'NSATs:          487'
# b'#'
# b'#      NIMu:    2'
# b'#      NIMs:    4'
# b'#    NAXIS1: 4096'
# b'#    NAXIS2: 4096'
# b'#    NPERTs:    0'
# b'#FOCUS_LEVi:    0.0000'
# b'#  FILENAME: ictj45b9q_flc.fits'
# b"#  FILTNAME: 'F814"
# b'#       PRE: ictj45b9q_flc'
# b'#      STEM: ictj45b9q'
# b'#      SUFF: fits'
# b'# FILT_INST: F814W'
# b'# EXPT_INST: 1345.0000'
# b'# EXPT_EFF : 1345.0000'
# b'# RDAT_INST: 2016.4879'
# b'# PROP_INST: 14118'
# b'#'
# b'WCSMODE: FIND'
# b'CALL FILL_WCS_INFO:'
# b'WCSMODE: FIND'
# b'FIND_WCSINFO...'
# b'MODE: FIND'
# b'rRA :    201.53648776238001       -47.636410410099003'
# b'rRA0:   -9999.0000000000000       -9999.0000000000000'
# b'----> find_obj:'
# b'---->      rRA:    201.53648776238001'
# b'---->      rDE:   -47.636410410099003'
# b'---->     NAME: NGC5139 OMC'
# b'---->     rRA0:    201.69123840332031'
# b'---->     rDE0:   -47.476943969726562'
# b'WCSMODE: FIND          NGC5139 OMC      201.69124 -47.47694           0.00      0.00'
# b'CALL FILL_WCS_INFO OBJ_NAME: NGC5139 OMC'
# b'CALL FILL_WCS_INFO   CRPIX1:    0.0000000000000000        0.0000000000000000'
# b'CALL FILL_WCS_INFO   CRVAL1:    201.69123840332031       -47.476943969726562'
# b'FIND_HISTMODE...'
# b'#  HISTMODE...  pixc (W/ SKYSUB):    33.44'
# b'DOAPPHOT:  F'
# b'--->  FOCUS_LEVi:    0.00000000'
# b'--->  FOCUS_LEVu:    0.00000000'
# b'---> PSFFILE_LIB: STDPSF_WFC3UV_F814W.fits'
# b'---> PSFFILE_USE: STDPSF_WFC3UV_F814W.fits'
# b'---> PSFFILE_PFF: STDPSF_WFC3UV_F814W.fits'
# b''
# b'HERE IS THE INFO ON THE PSF TO BE USED...'
# b''
# b'PSFFILE_LIB: STDPSF_WFC3UV_F814W.fits'
# b''
# b''
# b'*************************************'
# b'*************************************'
# b'**'
# b'**  GO THRU IMAGE AND FIND PEAKS...'
# b'**'
# b'**     HMIN:            5'
# b'**     FMIN:    1000.00000'
# b'13700 1627.509 3964.311 -10.899   40.9|5 912|   2721|   690  2442  2225   791|   574  2112   258  2084|      40    9501    9297'
# b'13800 1447.571 3989.190  -9.833  556.6|5 4 7|   2144|  1942   766   900   694|  1208   834   757   625|     556    6196    3927'
# b'13900 1426.449 4010.776  -8.616 1862.2|5 2 5|   2302|  1957  2186  1961  2028|  1662  2016  1988  2033|    1862    8549    4839'
# b'14000 2559.590 4036.268 -10.137   30.0|5 6 9|   2490|   210  1503  1100   358|   129  2055   103   229|      30    7150    7009'
# b'14100 2706.541 4060.727 -13.844   45.1|51215|  45486| 11280 43543 15201 34075|  4552 14751  8849 30988|      45  154094  153444'
# b'14200 1244.649 4088.959  -9.139   90.4|5 5 8|   1168|   112   517   784   257|   203   133   115   428|      90    2603    2239'
# b'------- -------- -------- ------- ------|- - -|-------| ----- ----- ----- -----| ----- ----- ----- -----| ------- ------- -------'
# b'N    XCEN     YCEN     MAG     SKY |MiSoS|   PCEN|   P02   P03   P04   P05|   P06   P07   P08   P09|    mSKY    F2x2 F2x2-SK'
# b'------- -------- -------- ------- ------|- - -|-------| ----- ----- ----- -----| ----- ----- ----- -----| ------- ------- -------'
# b''
# b'#   1    12261    0.073%   ..1..not on chip....'
# b'#   2 15135900   90.217%   ..2..not loc max....'
# b'#   3  1378934    8.219%   ..3..nearby brighter'
# b'#   4   122974    0.733%   ..4..flux too low...'
# b'#   5        0    0.000%   ..5..below mask thr.'
# b'#   6        0    0.000%   ..6..out of bounds..'
# b'#   7      572    0.003%   ..7..loflag issues..'
# b'#   8      926    0.006%   ..8..saturated......'
# b'#   9        0    0.000%   ..9..not contig sat.'
# b'#  10        0    0.000%   .10..not loc sat max'
# b'#  11        0    0.000%   .11..sat weirdness..'
# b'#  12        0    0.000%   .12..pk but not qsel'
# b'#  13    37794    0.225%   .13..pk too peaky...'
# b'#  14    14208    0.085%   .14..good unsat.....'
# b'#  15        0    0.000%   .15..good satd......'
# b''
# b''
# b'CRVAL_INST:       201.52841978      -47.62738516'
# b'CD1_1_OUTP:        -0.00000627       -0.00000909'
# b'CD2_1_OUTP:        -0.00000909        0.00000627'
# b'RCD1_1_OUTP:    -51407.19362196   -74498.48726901'
# b'RCD2_1_OUTP:    -74498.48726901    51407.19362196'
# b''
# b'CRVAL1_OUTP:       201.69123840      -47.47694397'
# b'CRPIX1_OUTP:         0.00000000        0.00000000'
# b'CD1_1_OUTP:        -0.00001389        0.00000000'
# b'CD2_1_OUTP:         0.00000000        0.00001389'
# b'RCD1_1_OUTP:    -71999.99999942        0.00000000'
# b'RCD2_1_OUTP:         0.00000000    71999.99999942'
# b''
# b''
# b'FIND BOUNDARY...'
# b''
# b'#'
# b'# CHIP_K  P_CRNR     XRAW        YRAW         XGC         YGC             UGC         VGC                  RA             Dec              UU          VV'
# b'#'
# b'# BDY_K1_P1:        1.000       1.000       1.000       1.000        6306.653   -9959.605        201.56130029    -47.61519819        6306.653   -9959.605'
# b'# BDY_K1_P2:     4095.000       1.000    4095.000       1.000        8150.639  -12643.906        201.52318868    -47.65243053        8150.639  -12643.906'
# b'# BDY_K1_P3:     4095.000    2047.000    4095.000    2047.000        9492.128  -11722.367        201.49557790    -47.63958785        9492.128  -11722.367'
# b'# BDY_K1_P4:        1.000    2047.000       1.000    2047.000        7648.139   -9038.068        201.53369981    -47.60236465        7648.139   -9038.068'
# b'#'
# b'# BDY_K2_P1:        1.000    2049.000       1.000    2049.000        7649.450   -9037.168        201.53367284    -47.60235210        7649.450   -9037.168'
# b'# BDY_K2_P2:     4095.000    2049.000    4095.000    2049.000        9493.439  -11721.466        201.49555091    -47.63957529        9493.439  -11721.466'
# b'# BDY_K2_P3:     4095.000    4095.000    4095.000    4095.000       10834.928  -10799.927        201.46795373    -47.62672599       10834.928  -10799.927'
# b'# BDY_K2_P4:        1.000    4095.000       1.000    4095.000        8990.936   -8115.631        201.50608592    -47.58951195        8990.936   -8115.631'
# b'#'
# b'FIND CLOSEST TO TARGET... Ns:        14208'
# b''
# b'DOMSORT...'
# b'---->   1:    0.0000000000000000'
# b'---->  Ns:    0.0000000000000000'
# b''
# b'SEPARATE READ-IN:'
# b'CRVAL1:    201.52841977593999       13:26:06.82'
# b'CRVAL2:   -47.627385161821003      -47:37:38.58'
# b''
# b'OUTPUT LISTS...'
# b'NLISTs:            1'
# b'SETUPa---           26'
# b'SETUPb ---        14208'
# b''
# b'--------------'
# b'FIND SPACING:'
# b'--------------'
# b'F01 (05:14)     u -- u ref-frame'
# b'F02 (04:14)     v -- v ref-frame'
# b'F03 (02:08)     M -- instl mag (1000s)'
# b'F04 (01:08)     x -- raw detector x pos'
# b'F05 (01:08)     y -- raw detector y pos'
# b'F06 (02:08)     m -- instl mag'
# b'F07 (02:02)     k -- detector chip no'
# b'F08 (01:08)     X -- dist-cor x posn'
# b'F09 (01:08)     Y -- dist-cor y posn'
# b'F10 (02:02)     h -- local isolation'
# b'F11 (04:08)     H -- list-based isolatn'
# b'F12 (05:15)     r -- RA (deg)'
# b'F13 (05:15)     d -- Dec (deg)'
# b'F14 (01:11)     R -- RA (sexig)'
# b'F15 (01:12)     D -- Dec (sexig)'
# b'F16 (03:06)     i -- peak pixel column'
# b'F17 (03:06)     j -- peak pixel row'
# b'F18 (05:12)     p -- peak pixel value'
# b'F19 (08:12)     q -- quality of fit'
# b'F20 (07:12)     c -- chisq of fit'
# b'F21 (05:14)     U -- u ref-frame (corr)'
# b'F22 (04:14)     V -- v ref-frame (corr)'
# b'F23 (01:01)     k -- chip number'
# b'F24 (01:02)     K -- chip number (w/K)'
# b'F25 (04:10)     s -- sky value'
# b'F26 (01:06)     n -- star number'
# b''
# b'*********************'
# b'***'
# b'*** NLISTs:            1'
# b'***'
# b'*********************'
# b''
# ictj45ajq_flc.xympqks
# ictj45b9q_flc.xympqks
# ictj46cuq_flc.xympqks
# ictj46czq_flc.xympqks

# %% [markdown]
# ### See the output catalogs

# %%
# If you already have the output catalogs, and dont want to rerun hst1pass
catalogs = [im.replace('.fits', '.xympqks') for im in input_images]

# %%
catalogs
# Out:
# ['ictj45ajq_flc.xympqks',
#  'ictj45b9q_flc.xympqks',
#  'ictj46cuq_flc.xympqks',
#  'ictj46czq_flc.xympqks']

# %% [markdown]
# 'If ran with the flag `focus = -1` (uses focus dependent PSF) focus of image can be output

# %%
from psf_tools.PSFPhot import check_focus

# %%
check_focus(catalogs)
# Out:
# {'ictj45ajq_flc.xympqks': 0.0,
#  'ictj45b9q_flc.xympqks': 0.0,
#  'ictj46cuq_flc.xympqks': 0.0,
#  'ictj46czq_flc.xympqks': 0.0}

# %%
output_catalogs = []
for im in input_images:
    cat_str = im.replace('.fits', '_sci?_xyrd.cat')
    output_catalogs += glob.glob(cat_str)
output_catalogs = sorted(output_catalogs)

# %% [markdown]
# ##### The hst1pass files are broken up per chip.  The following catalogs should be used for the exposure level analysis

# %%
Table.read('ictj45ajq_flc_sci1_xyrd.cat', format='ascii.commented_header')
# Out:
# <Table length=7226>
#    x        y             r          ...    p        q       s
# float64  float64       float64       ... float64  float64 float64
# -------- -------- ------------------ ... -------- ------- -------
# 3161.462    5.393 201.53878582782485 ...   465.42   0.816   32.91
# 3456.623    5.509 201.53576201399736 ... 10127.43   0.036   61.39
#      ...      ...                ... ...      ...     ...     ...
# 2161.211 2040.743 201.52148625332956 ...   498.82   0.126   36.64
#  3060.84 2040.752 201.51229751438623 ...   991.29   0.089   31.18
# 1648.016 2042.175 201.52668624588918 ... 13464.14   0.029   54.54

# %%
output_catalogs
# Out:
# ['ictj45ajq_flc_sci1_xyrd.cat',
#  'ictj45ajq_flc_sci2_xyrd.cat',
#  'ictj45b9q_flc_sci1_xyrd.cat',
#  'ictj45b9q_flc_sci2_xyrd.cat',
#  'ictj46cuq_flc_sci1_xyrd.cat',
#  'ictj46cuq_flc_sci2_xyrd.cat',
#  'ictj46czq_flc_sci1_xyrd.cat',
#  'ictj46czq_flc_sci2_xyrd.cat']

# %% [markdown]
# # Python interface<a id="python"></a>

# %% [markdown]
# A fully python based interface is  available for the PSF fitting.  The python interface has a pared down feature set, and does not yet support the focus based PSFs (coming soon!), and runs slower, but has a more familiar usage compared to the Fortran interface.   The fortran interface can also much more reliably measure UVIS saturated stars, whereas the Python interface cannot. The output `xyrd` catalogs are the same as the fortran, and so either interface can be selected for use for the initial fittings, and then the following alignment/collating steps are the same.

# %% [markdown]
# ### Look at inputs

# %%
run_python_psf_fitting?
# Out:
# Signature:
# run_python_psf_fitting(
#     input_images,
#     psf_model_file=None,
#     hmin=5,
#     fmin=1000.0,
#     pmax=70000.0,
#     qmax=0.5,
#     cmin=-1.0,
#     cmax=0.1,
#     ncpu=None,
#     focus_only=False,
# )
# Docstring:
# Main function to run to do finding/PSF fitting of stars with python engine
#
# This is the top level function of the python PSF photometry interface.
# This gets the PSF and other information, loops over the images and calls
# the fitting functions.  The inputs control the star finding/rejection
# criteria.  The outputs photometric catalogs are saved as ascii tables.
#
# Note: Focus dependent PSFs not yet supported in the python engine (but
# are coming soon)
#
# Parameters
# ----------
# input_images : list
#     List of image filenames (strings) to measure.  Must be fits files.
# psf_model_file : str, optional
#     Name of fits file containing PSF model.  If None (default),
#     finds/downloads the appropriate model from WFC3 website.
# hmin : int, optional
#     Minimum separation (in pixels) between peaks for them to be measured.
#     Default 5.
# fmin : float, optional
#     Minimum flux (in image units) in the central 2x2 pixels for a source
#     to be measured. Default 1000.
# pmax : float, optional
#     Maximum flux (in image units) of the brightest pixel in a source for
#     it to be measured. Default 70000 (saturation threshold).  Setting this
#     slightly lower is likely advantageous, as the python interface cannot
#     measure saturated UVIS stars well.
# qmax : float, optional
#     Maximum fit quality for fit of a given star to be considered good.
#     Fit quality is defined as:
#     sum(abs((data - sky - fitted_model)/fitted_flux)))
# cmin : float, optional
#     Minimum scaled residual of the central pixel for the measurement to be
#     considered good.  Scaled residual is defined as:
#     (peak pixel value - sky - fit peak pixel value)/fitted_flux.
#     This helps reject extended/diffuse sources.  Default -1.
# cmax : float, optional
#     Maximum scaled residual of the central pixel for the measurement to be
#     considered good (see cmin).  Default 0.1.  Helps reject cosmic rays.
# ncpu : int, optional
#     Number of CPUs to use to distribute fitting across.  If None, uses
#     all cpus.  Default None.
# File:      /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/PyFitting.py
# Type:      function

# %% [markdown]
# In general, the parameters to the python interface are very similar.  More of the keyword arguments are specified directly (qmax, cmin, cmax), and have docstrings specifying their use.  You can also specify the number of CPUs to distribute the fitting across, which subtrantially improves performance when > 1 (default is to use all CPUs).

# %% [markdown]
# ### Run the python fitting

# %%
run_python_psf_fitting(input_images, hmin=hmin, fmin=fmin, pmax=pmax)
# Out:
# Using PSF file STDPSF_WFC3UV_F814W.fits
# ictj45ajq_flc.fits
# Rejected 13608 of 28067 sources for being too peaked
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 run_python_psf_fitting(input_images, hmin=hmin, fmin=fmin, pmax=pmax)
#
# File /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/PyFitting.py:143, in run_python_psf_fitting(input_images, psf_model_file, hmin, fmin, pmax, qmax, cmin, cmax, ncpu, focus_only)
#     141 for ext in exts:
#     142     data = fits.getdata(im , extname='SCI', extver=ext)
# --> 143     tbl = measure_stars(data, mods[ext-1], hmin, fmin, pmax,
#     144                         qmax, cmin, cmax, ncpu, focus_only)
#     146     tbl['x'] += 1.
#     147     tbl['y'] += 1.
#
# File /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/PyFitting.py:230, in measure_stars(data, mod, hmin, fmin, pmax, qmax, cmin, cmax, ncpu, focus_only)
#     226         return foc_tbl
#     228 # Measure the remaining candidates
# --> 230 tbl = do_stars_mp(xs, ys, skies, mod, data, ncpu)
#     231 # Last rejection pass
#     232 final_good_mask = (tbl['q']<qmax) & (tbl['cx']<cmax) & (tbl['cx']>cmin)
#
# File /grp/hst/wfc3i/irivera/repos/wfc3_photometry/psf_tools/PyFitting.py:423, in do_stars_mp(xs, ys, skies, mod, data, ncpu)
#     420 else:
#     421     p = Pool(ncpu)
# --> 423 result = p.starmap(fit_func, xy_sky)
#     424 p.close()
#     425 p.join()
#
# File /user/irivera/linux/miniconda3/envs/stenv/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /user/irivera/linux/miniconda3/envs/stenv/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File /user/irivera/linux/miniconda3/envs/stenv/lib/python3.11/multiprocessing/pool.py:540, in Pool._handle_tasks(taskqueue, put, outqueue, pool, cache)
#     538     break
#     539 try:
# --> 540     put(task)
#     541 except Exception as e:
#     542     job, idx = task[:2]
#
# File /user/irivera/linux/miniconda3/envs/stenv/lib/python3.11/multiprocessing/connection.py:206, in _ConnectionBase.send(self, obj)
#     204 self._check_closed()
#     205 self._check_writable()
# --> 206 self._send_bytes(_ForkingPickler.dumps(obj))
#
# File /user/irivera/linux/miniconda3/envs/stenv/lib/python3.11/multiprocessing/reduction.py:51, in ForkingPickler.dumps(cls, obj, protocol)
#      48 @classmethod
#      49 def dumps(cls, obj, protocol=None):
#      50     buf = io.BytesIO()
# ---> 51     cls(buf, protocol).dump(obj)
#      52     return buf.getbuffer()
#
# PicklingError: Can't pickle <functools._lru_cache_wrapper object at 0x7fe686a9f3d0>: it's not the same object as photutils.psf.griddedpsfmodel.GriddedPSFModel._calc_interpolator_uncached

# %% [markdown]
# ### Look at one of the xyrd catalogs

# %% [markdown]
# The xyrd catalogs contain the outputs from the fitting.  Depending on what was selected in the fitting parameters, the number of columns may vary.  However, the important columns are:
#
# `x`, `y`: The pixel positions of the source measured (1-indexed)
#
# `r`, `d`: The decimal degree RA and Dec of the source measured
#
# `m`: The instrumental magnitude of the fitted PSF (`-2.5 * np.log10(flux [electrons])`)
#
# `q`: The fit quality (see docstring of `run_python_psf_fitting()` for more info)

# %%
Table.read(output_catalogs[0], format='ascii.commented_header')

# %% [markdown]
# # 2. Align the images <a id="align"></a>

# %% [markdown]
# With the image based catalogs, we can now align them using the accurate positions from the PSF fitting steps.  The alignment not only removes pointing error between images, but also makes the images/catalogs useful for astrometric studies.  This step also corrects the RAs/Decs in the catalogs with the updated values resulting from the alignment.  Furthermore, aligning the images is crucial for tbe final matching/averaging step.

# %% [markdown]
# ### See options for aligning the images using the catalogs from previous step

# %%
align_images?

# %% [markdown]
# Setting `gaia=True` will automatically download and align the catalogs to Gaia DR2 (no proper motions added due to low precision of Gaia proper motions).  This yields high accuracy absolute astrometric measurements!

# %%
align_images(input_images, searchrad=1.5, gaia=True, wcsname='DEMO', prop=True)

# %% [markdown]
# ### Can also run with any arguments passed to TweakReg

# %%
align_images(input_images, searchrad=.1, gaia=True, fluxcol=5, maxflux=-14., minflux=-11., fluxunits='mag')

# %% [markdown]
# #### Can look at shift file, saved as shifts.txt

# %% [markdown]
# The columns here are `xshift`, `yshift` (pixels), `rotation` (deg), `scale`, `xrms`, and `yrms`(pixels)

# %%
cat shifts.txt

# %% [markdown]
# Aligning to gaia may result in slightly higher RMS values than aligning relatively (`gaia=False` and  `reference_catalog=None`) due to proper motions/inaccuracies in the gaia catalog.

# %%
align_images(input_images, searchrad=.1, fluxcol=5, maxflux=-14., minflux=-11., fluxunits='mag')

# %%
cat shifts.txt

# %% [markdown]
# # 3 Match/Average the catalogs into final catalog<a id="average"></a>

# %% [markdown]
# The final step takes the astrometrically corrected images/catalogs, and matches common stars between them, averaging those measurements into one final catalog as well as providing errors on each of those measurements, while clipping erroneous values.  It also flux calibrates (applies aperture, pixel area map, and zerpoint correction) the magnitudes, to make them ready for science!  This software also has the ability to produce a simple drizzled image of the input images, as to have a corresponding data file

# %% [markdown]
# ### See options for final collation of the table

# %%
make_final_table?

# %%
tbl_i = make_final_table(input_images, min_detections=3)

# %%
tbl_i

# %% [markdown]
# # 4. See the results!<a id="results"></a>
# The columns are mbar, rbar, dbar, qbar, xbar, and ybar which are mean magnitude (instrumental), RA, Dec, Q (fit quality), X position in the output frame, and Y position in the output frame.  The columns ending in 'std' are the standard deviations of the values.  The column 'n' is the number of times that source was detected (and not clipped out from the averaging).  The column `n_expected` is the number of images that covered that sky position, and thus the total number of times that star could have been detected by the input images.

# %% [markdown]
# ### To access a column from the table, the syntax is `tbl[<colname>]` as seen below

# %%
tbl_i = Table.read('F814W_final_cat.txt', format='ascii.commented_header')

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(tbl_i['rbar'], tbl_i['dbar'], c=tbl_i['mbar'], s = 8, alpha=.3)
plt.xlim(plt.xlim()[::-1]) # reverse x axis for RA
plt.xlabel('RA')
plt.xlabel('Dec')
cb = plt.colorbar()
cb.set_label('I [mag]')
plt.grid(ls=':')

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(tbl_i['mbar'], tbl_i['mstd'], c=tbl_i['qbar'], s = 8, alpha=.3, vmin=0., vmax=.1, cmap='viridis')
plt.ylim(-.0,.1)
plt.xlabel('I [mag]')
plt.ylabel('$\sigma_I$')
cb = plt.colorbar()
cb.set_label('qbar')
plt.grid(ls=':')

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(tbl_i['xstd'], tbl_i['ystd'], s = 5, alpha=.25, c=tbl_i['mbar'], cmap='viridis')
plt.xlim(0.0001, 1)
plt.ylim(0.0001, 1)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('xstd')
plt.ylabel('ystd')
cb = plt.colorbar()
cb.set_label('mbar [mag]')
plt.grid(ls=':')

# %%
# stat, bedges, bn = binned_statistic(tbl['mbar'], tbl['xstd'],statistic=np.nanmedian, bins=20)
fig = plt.figure(figsize=(10,10))
plt.scatter(tbl_i['mbar'], tbl_i['xstd'], s=6, alpha=.4, c=tbl_i['qbar'], vmin=0, vmax=.2, cmap='viridis')

plt.xlabel('$\overline{m}$')
plt.ylabel('x std')
plt.grid(ls=':')
plt.ylim(-.0,.1)
plt.xlim(17, 27)

# %% [markdown]
# ### Tables can be matched as well:

# %%
gaia_tbl = Table.read('gaia.cat', format='ascii.commented_header')
gaia_tbl['ra'].name = 'rbar'
gaia_tbl['dec'].name = 'dbar'
matched_i, matched_gaia = match_final_catalogs(tbl_i, gaia_tbl, max_distance=.04)

# %%
plt.scatter(matched_i['mbar'], (matched_i['rbar'] - matched_gaia['rbar'])*3600., s=4, alpha=.4)
plt.xlim(17., 22.)
plt.ylim(-.01, .01)
plt.ylabel('delta RA [arcsec]')
plt.xlabel('mbar')
plt.grid(ls=':')

# %%
plt.scatter(matched_i['mbar'], (matched_i['dbar'] - matched_gaia['dbar'])*3600., s=4, alpha=.4)
plt.xlim(17., 22.)
plt.ylim(-.01, .01)
plt.ylabel('delta DEC [arcsec]')
plt.xlabel('mbar')
plt.grid(ls=':')

# %% [markdown]
# ### Match tables from two filters

# %% [markdown]
# Run the same steps, with the F606W images to get an averaged catalog of those files.  Then we can match the F814W and F606W tables and make a simple CMD

# %%
v_images =  [im for im in files if fits.getval(im, 'FILTER')=='F606W']
v_images =  [im for im in v_images if fits.getval(im, 'EXPTIME')>200]
run_hst1pass(v_images, hmin=hmin, fmin=fmin, pmax=pmax)
align_images(v_images, searchrad=1., gaia=True)
tbl_v = make_final_table(v_images, min_detections=3)

# %%
tbl_v = Table.read('F606W_final_cat.txt', format='ascii.commented_header')

# %%
matched_i, matched_v = match_final_catalogs(tbl_i, tbl_v)

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(matched_v['mbar'] - matched_i['mbar'], matched_v['mbar'], s=3, alpha=.3)
plt.ylim(plt.ylim()[::-1])
plt.xlabel('V - I [mag]')
plt.ylabel('V [mag]')
plt.title('Color Magnitude Diagram')
plt.xlim(-1,1)
plt.ylim(28, 17)

# %% [markdown]
# # 4. Using models for other analysis
# In addition to fitting stars in clusters, there are also tools for using the PSF models for addition/subtraction of stars

# %%
from psf_tools.PyFitting import subtract_psfs, make_models, get_subtrahend
from matplotlib.colors import LogNorm

# %%
data = fits.getdata('ictj45ajq_flc.fits')
mod1, mod2 = make_models('../psf_tools/PSFSTD_WFC3UV_F814W.fits')
cat = Table.read('ictj45ajq_flc_sci1_xyrd.cat', format='ascii.commented_header')
subbed = subtract_psfs(data, cat, mod1)

# %%
plt.figure(figsize=(15,7))
plt.imshow(data, vmin=12, vmax=1100, norm=LogNorm(), origin='lower')
plt.xlim(0, 500)
plt.ylim(0, 500)

# %%
plt.figure(figsize=(15,7))
plt.imshow(subbed, vmin=12, vmax=1100, norm=LogNorm(), origin='lower')
plt.xlim(0, 500)
plt.ylim(0, 500)

# %%
fluxes = np.power(10, cat['m']/-2.5).data
# subtrahend = get_subtrahend(cat['x'], cat['y'], fluxes, mod1, data.shape)
plt.figure(figsize=(15,7))
plt.imshow(np.abs(subtrahend), vmin=.001, vmax=1100, norm=LogNorm(), origin='lower')
plt.xlim(0, 500)
plt.ylim(0, 500)
